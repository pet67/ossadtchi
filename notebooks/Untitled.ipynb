# %%
files_list = files_list.split()

# %%
import json

# %%
files_list[0]
# Out:
# '/home/amplifier/common/pet67_paper/data/101218/10_right_little_60s_12-10_16-43-53.mat'

# %%
out = []
for i in range(64):
    current = {
        "name": f"single_{i}",
        "channels": f"[{i}]",
    }
    out.append(current)

# %%
with open("out.json", 'w') as outfile:
    json.dump(out, outfile, indent=" " * 4)

# %%
import json

with open('../configs/datasets_config.json') as f:
    d = json.load(f)

# %%
d
# Out:
# [{'name': '030319_MGMSU_Klimashova/10_right_little_60s_03-03_17-17-50',
#   'path': '/home/amplifier/common/DATA/ECOG/030319_MGMSU_Klimashova/mat_converted/10_right_little_60s_03-03_17-17-50.mat',
#   'filename': '10_right_little_60s_03-03_17-17-50.mat',
#   'targets': [4],
#   'group': '030319_MGMSU_Klimashova',
#   'patient': 'Klimashova',
#   'source': 'MGMSU',
#   'date': '03/03/2019'},
#  {'name': '030319_MGMSU_Klimashova/10_right_little_60s_03-03_17-19-02',
#   'path': '/home/amplifier/common/DATA/ECOG/030319_MGMSU_Klimashova/mat_converted/10_right_little_60s_03-03_17-19-02.mat',
#   'filename': '10_right_little_60s_03-03_17-19-02.mat',
#   'targets': [4],
#   'group': '030319_MGMSU_Klimashova',
#   'patient': 'Klimashova',
#   'source': 'MGMSU',
#   'date': '03/03/2019'},
#  {'name': '030319_MGMSU_Klimashova/1_left_little_60s_03-03_17-23-21',
#   'path': '/home/amplifier/common/DATA/ECOG/030319_MGMSU_Klimashova/mat_converted/1_left_little_60s_03-03_17-23-21.mat',
# ...
